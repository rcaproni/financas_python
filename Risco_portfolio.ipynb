# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb

# %%
#tickers
tickers = ['ABCB4.SA', 'AZUL4.SA', 'BBAS3.SA', 'BBDC4.SA', 'BRDT3.SA', 'BRSR6.SA', 'CARD3.SA', 'CCRO3.SA', 'COGN3.SA', 'EGIE3.SA', 'EZTC3.SA', 'ITSA4.SA', 'JHSF3.SA', 'LCAM3.SA', 'LEVE3.SA', 'MEAL3.SA', 'MOVI3.SA', 'OIBR3.SA', 'PRIO3.SA', 'RAIL3.SA', 'SAPR11.SA', 'SCAR3.SA', 'SHUL4.SA', 'TAEE11.SA', 'TECN3.SA', 'TRPL4.SA', 'VIVT4.SA', 'VULC3.SA', 'VVAR3.SA']
#weight for each ticker
weights = np.array([0.02265560139, 0.0132791836, 0.06057895305, 0.07859779156, 0.02740391553, 0.02278396174, 0.05603031056, 0.01114239131, 0.02005375752, 0.02545064797, 0.06173348307, 0.06291185143, 0.01239925304, 0.07201550349, 0.03689840447, 0.00921953292, 0.0765272169, 0.003226836522, 0.06523201566, 0.004714186584, 0.03826360845, 0.01533829752, 0.04457771508, 0.03268095205, 0.003309608572, 0.02472036927, 0.02514528278, 0.01688804497, 0.05622132299])

# %%
#get data in yahoo finance
sec_data = pd.DataFrame()
for t in tickers:
    sec_data[t]=wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
sec_data.tail()
# Out:
#             ABCB4.SA   AZUL4.SA   BBAS3.SA   BBDC4.SA   BRDT3.SA  BRSR6.SA  \
# Date
# 2020-11-17     14.05  32.849998  34.200001  25.400000  21.690001     12.81
# 2020-11-18     14.00  34.299999  34.279999  24.620001  21.180000     12.75
# 2020-11-19     13.84  35.680000  34.619999  24.639999  21.010000     12.78
# 2020-11-23     13.98  35.619999  34.520000  24.480000  20.350000     12.89
# 2020-11-24     14.46  35.860001  35.820000  25.830000  21.090000     13.42
#
#             CARD3.SA  CCRO3.SA  COGN3.SA   EGIE3.SA  ...   RAIL3.SA  \
# Date                                                 ...
# 2020-11-17     13.80     12.63      4.87  45.740002  ...  18.799999
# 2020-11-18     13.83     12.62      5.13  44.700001  ...  18.370001
# 2020-11-19     14.00     12.70      4.98  44.009998  ...  18.600000
# 2020-11-23     14.57     12.30      5.04  43.009998  ...  19.200001
# 2020-11-24     14.45     12.90      5.04  42.930000  ...  19.530001
#
# ...

# %%
sec_data.head()
# Out:
#             ABCB4.SA  AZUL4.SA   BBAS3.SA  BBDC4.SA  BRDT3.SA  BRSR6.SA  \
# Date
# 2007-09-26  6.271255       NaN  15.925868       NaN       NaN       NaN
# 2007-09-27  6.271255       NaN  16.571508       NaN       NaN       NaN
# 2007-09-28  6.363449       NaN  16.619928       NaN       NaN       NaN
# 2007-10-01  6.432593       NaN  16.899712       NaN       NaN       NaN
# 2007-10-02  6.423385       NaN  17.190252       NaN       NaN       NaN
#
#             CARD3.SA  CCRO3.SA  COGN3.SA  EGIE3.SA  ...  RAIL3.SA  SAPR11.SA  \
# Date                                                ...
# 2007-09-26  5.643761  3.147112       NaN  8.384393  ...       NaN        NaN
# 2007-09-27  5.614965  3.208475       NaN  8.237939  ...       NaN        NaN
# 2007-09-28  5.614965  3.234775       NaN  8.256249  ...       NaN        NaN
# 2007-10-01  5.974900  3.393445       NaN  8.468601  ...       NaN        NaN
# 2007-10-02  6.010892  3.340847       NaN  8.680961  ...       NaN        NaN
#
# ...

# %%
sec_returns = np.log(sec_data/sec_data.shift(1)) #retorno logaritmico
sec_returns
# Out:
#             ABCB4.SA  AZUL4.SA  BBAS3.SA  BBDC4.SA  BRDT3.SA  BRSR6.SA  \
# Date
# 2007-09-26       NaN       NaN       NaN       NaN       NaN       NaN
# 2007-09-27  0.000000       NaN  0.039740       NaN       NaN       NaN
# 2007-09-28  0.014594       NaN  0.002918       NaN       NaN       NaN
# 2007-10-01  0.010807       NaN  0.016694       NaN       NaN       NaN
# 2007-10-02 -0.001433       NaN  0.017046       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2020-11-17 -0.006385  0.021539  0.014573  0.005527 -0.008265  0.017323
# 2020-11-18 -0.003565  0.043194  0.002336 -0.031190 -0.023794 -0.004695
# 2020-11-19 -0.011494  0.039445  0.009869  0.000812 -0.008059  0.002350
# 2020-11-23  0.010065 -0.001683 -0.002893 -0.006515 -0.031918  0.008570
# 2020-11-24  0.033759  0.006715  0.036968  0.053680  0.035718  0.040294
#
#             CARD3.SA  CCRO3.SA  COGN3.SA  EGIE3.SA  ...  RAIL3.SA  SAPR11.SA  \
# ...

# %%
#variancia do portfolio anualizada
port_variance = np.dot(weights.T, np.dot(sec_returns.cov()*250, weights))
port_variance
# Out:
# 0.14863854059033482

# %%
#volatilidade do portfolio
port_vol = (np.dot(weights.T, np.dot(sec_returns.cov()*250, weights)))**0.5
print('Volatilidade do portfolio= '+ str(round(port_vol, 5)*100)+' %')
# Out:
# Volatilidade do portfolio= 38.554 %
